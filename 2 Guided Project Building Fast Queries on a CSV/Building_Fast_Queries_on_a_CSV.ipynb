# %%
# import csv
# with open('laptops.csv', encoding = 'latin-1') as file:
#     reader = csv.reader(file)
#     header = next(reader)
#     rows = list(reader)

# %%
print(header)
# Out:
# ['Id', 'Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price_euros']

# %%
print(rows[0:5])
# Out:
# [['1', 'Apple', 'MacBook Pro', 'Ultrabook', '13.3', 'IPS Panel Retina Display 2560x1600', 'Intel Core i5 2.3GHz', '8GB', '128GB SSD', 'Intel Iris Plus Graphics 640', 'macOS', '1.37kg', '1339.69'], ['2', 'Apple', 'Macbook Air', 'Ultrabook', '13.3', '1440x900', 'Intel Core i5 1.8GHz', '8GB', '128GB Flash Storage', 'Intel HD Graphics 6000', 'macOS', '1.34kg', '898.94'], ['3', 'HP', '250 G6', 'Notebook', '15.6', 'Full HD 1920x1080', 'Intel Core i5 7200U 2.5GHz', '8GB', '256GB SSD', 'Intel HD Graphics 620', 'No OS', '1.86kg', '575.00'], ['4', 'Apple', 'MacBook Pro', 'Ultrabook', '15.4', 'IPS Panel Retina Display 2880x1800', 'Intel Core i7 2.7GHz', '16GB', '512GB SSD', 'AMD Radeon Pro 455', 'macOS', '1.83kg', '2537.45'], ['5', 'Apple', 'MacBook Pro', 'Ultrabook', '13.3', 'IPS Panel Retina Display 2560x1600', 'Intel Core i5 3.1GHz', '8GB', '256GB SSD', 'Intel Iris Plus Graphics 650', 'macOS', '1.37kg', '1803.60']]

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line between rows
        
    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %%
explore_data(rows,0,5)
# Out:
# ['1', 'Apple', 'MacBook Pro', 'Ultrabook', '13.3', 'IPS Panel Retina Display 2560x1600', 'Intel Core i5 2.3GHz', '8GB', '128GB SSD', 'Intel Iris Plus Graphics 640', 'macOS', '1.37kg', '1339.69']
#
#
# ['2', 'Apple', 'Macbook Air', 'Ultrabook', '13.3', '1440x900', 'Intel Core i5 1.8GHz', '8GB', '128GB Flash Storage', 'Intel HD Graphics 6000', 'macOS', '1.34kg', '898.94']
#
#
# ['3', 'HP', '250 G6', 'Notebook', '15.6', 'Full HD 1920x1080', 'Intel Core i5 7200U 2.5GHz', '8GB', '256GB SSD', 'Intel HD Graphics 620', 'No OS', '1.86kg', '575.00']
#
#
# ['4', 'Apple', 'MacBook Pro', 'Ultrabook', '15.4', 'IPS Panel Retina Display 2880x1800', 'Intel Core i7 2.7GHz', '16GB', '512GB SSD', 'AMD Radeon Pro 455', 'macOS', '1.83kg', '2537.45']
#
#
# ['5', 'Apple', 'MacBook Pro', 'Ultrabook', '13.3', 'IPS Panel Retina Display 2560x1600', 'Intel Core i5 3.1GHz', '8GB', '256GB SSD', 'Intel Iris Plus Graphics 650', 'macOS', '1.37kg', '1803.60']

# %% [markdown]
# ## Cleaning up the dataset
#
# 1. Convert ID column to integer
# 2. Convert Inches to float
# 3. Convert price_euros to float

# %%
import csv
class Inventory:
    def __init__(self, csv_filename):
        with open(csv_filename, encoding = 'latin-1') as file:
            reader = csv.reader(file)
            self.data = list(reader)
            self.header = self.data[0]
            self.rows = self.data[1:]
            for row in self.rows:
                price  = row[12]
                price_split = price.split('.')
                row[12] = price_split[0]
            self.id_to_row = {}
            for row in self.rows:
                self.id_to_row[row[0]] = row
            self.prices = []
            for row in self.rows:
                self.prices.append(str(row[12]))
            self.rows_by_price = sorted(self.rows[12])
    def get_laptop_from_id_fast(self, laptop_id):
        if laptop_id in self.id_to_row.keys():
            return self.id_to_row[laptop_id]
        else:
            'None'
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:
            if row[0] == laptop_id:
                return row
    def check_promotion_dollars(self, dollars): 
        for row in self.rows:
            if row[12] == dollars:
                return True
    def check_promotion_dollars_fast(self, dollars):
        dollars = str(dollars)
        if dollars in self.prices:
            return True

# %%
x = Inventory('laptops.csv')
x.header
# Out:
# ['Id',
#  'Company',
#  'Product',
#  'TypeName',
#  'Inches',
#  'ScreenResolution',
#  'Cpu',
#  'Ram',
#  'Memory',
#  'Gpu',
#  'OpSys',
#  'Weight',
#  'Price_euros']

# %%
len(x.rows)
# Out:
# 1303

# %%
print(x.get_laptop_from_id('3'))
# Out:
# ['3', 'HP', '250 G6', 'Notebook', '15.6', 'Full HD 1920x1080', 'Intel Core i5 7200U 2.5GHz', '8GB', '256GB SSD', 'Intel HD Graphics 620', 'No OS', '1.86kg', '575']

# %%
x.get_laptop_from_id_fast('2')
# Out:
# ['2',
#  'Apple',
#  'Macbook Air',
#  'Ultrabook',
#  '13.3',
#  '1440x900',
#  'Intel Core i5 1.8GHz',
#  '8GB',
#  '128GB Flash Storage',
#  'Intel HD Graphics 6000',
#  'macOS',
#  '1.34kg',
#  '898']

# %%
x.id_to_row['4']
# Out:
# ['4',
#  'Apple',
#  'MacBook Pro',
#  'Ultrabook',
#  '15.4',
#  'IPS Panel Retina Display 2880x1800',
#  'Intel Core i7 2.7GHz',
#  '16GB',
#  '512GB SSD',
#  'AMD Radeon Pro 455',
#  'macOS',
#  '1.83kg',
#  '2537']

# %%
x.get_laptop_from_id_fast('5')
# Out:
# ['5',
#  'Apple',
#  'MacBook Pro',
#  'Ultrabook',
#  '13.3',
#  'IPS Panel Retina Display 2560x1600',
#  'Intel Core i5 3.1GHz',
#  '8GB',
#  '256GB SSD',
#  'Intel Iris Plus Graphics 650',
#  'macOS',
#  '1.37kg',
#  '1803']

# %%
x.get_laptop_from_id_fast('8')
# Out:
# ['8',
#  'Apple',
#  'Macbook Air',
#  'Ultrabook',
#  '13.3',
#  '1440x900',
#  'Intel Core i5 1.8GHz',
#  '8GB',
#  '256GB Flash Storage',
#  'Intel HD Graphics 6000',
#  'macOS',
#  '1.34kg',
#  '1158']

# %%
print(x.get_laptop_from_id_fast('7') )
# Out:
# ['7', 'Apple', 'MacBook Pro', 'Ultrabook', '15.4', 'IPS Panel Retina Display 2880x1800', 'Intel Core i7 2.2GHz', '16GB', '256GB Flash Storage', 'Intel Iris Pro Graphics', 'Mac OS X', '2.04kg', '2139']

# %%
import time
import random

N = 10000

ids = [random.randint(1000000, 9999999) for _ in range(N)]

ids = str(ids)

x = Inventory('laptops.csv')

total_time_no_dict = 0 

for each in ids:
    start = time.time()
    x.get_laptop_from_id(each)
    end = time.time()
    total_time_no_dict = end - start

total_time_dict = 0
for each in ids:
    start = time.time()
    x.get_laptop_from_id_fast(each)
    end = time.time()
    total_time_dict = end - start

print(total_time_no_dict,total_time_dict)
# Out:
# 4.982948303222656e-05 9.5367431640625e-07

# %% [markdown]
# ## Time Complexity Comparison: Dictionary vs. Loop
#
# * Loop Retrieval = 0.00004982948303222656
# * Dictionary Retrieval = 0.00000095367431640625
#
# The Dictionary lookup is 52 times faster than the loop retrieval

# %%
x.prices
# Out:
# ['1339',
#  '898',
#  '575',
#  '2537',
#  '1803',
#  '400',
#  '2139',
#  '1158',
#  '1495',
#  '770',
#  '393',
#  '344',
#  '2439',
#  '498',
#  '1262',
#  '1518',
#  '745',
#  '2858',
#  '499',
#  '979',
#  '191',
#  '999',
#  '258',
#  '819',
#  '659',
#  '418',
#  '1099',
#  '800',
#  '1298',
#  '896',
#  '244',
#  '199',
#  '439',
#  '1869',
#  '998',
#  '249',
#  '367',
#  '979',
#  '488',
#  '879',
#  '389',
#  '1499',
#  '522',
#  '682',
#  '999',
#  '1419',
#  '369',
#  '1299',
#  '639',
#  '466',
#  '319',
#  '841',
#  '398',
#  '1103',
#  '384',
#  '767',
#  '439',
#  '586',
#  '2449',
#  '415',
#  '1299',
#  '879',
#  '599',
#  '941',
#  '690',
#  '1983',
#  '438',
#  '229',
#  '549',
#  '949',
#  '1089',
#  '955',
#  '870',
#  '1095',
#  '389',
#  '949',
#  '519',
#  '855',
#  '530',
#  '977',
#  '1096',
#  '1510',
#  '860',
#  '399',
#  '395',
#  '1349',
#  '699',
#  '598',
#  '1449',
#  '1649',
#  '699',
#  '689',
#  '1197',
#  '1195',
#  '1049',
#  '847',
#  '599',
#  '485',
#  '577',
#  '1249',
#  '719',
#  '349',
#  '647',
#  '1119',
#  '1340',
#  '659',
#  '414',
#  '1193',
#  '1299',
#  '1480',
#  '1262',
#  '1379',
#  '1399',
#  '722',
#  '1629',
#  '1398',
#  '1084',
#  '1130',
#  '564',
#  '1118',
#  '479',
#  '2241',
#  '629',
#  '1271',
#  '451',
#  '259',
#  '812',
#  '277',
#  '1396',
#  '928',
#  '638',
#  '449',
#  '884',
#  '572',
#  '598',
#  '988',
#  '252',
#  '938',
#  '499',
#  '699',
#  '655',
#  '1116',
#  '869',
#  '602',
#  '369',
#  '1099',
#  '2014',
#  '344',
#  '2029',
#  '447',
#  '1249',
#  '899',
#  '498',
#  '1890',
#  '1082',
#  '619',
#  '629',
#  '1315',
#  '1049',
#  '447',
#  '403',
#  '805',
#  '728',
#  '1079',
#  '348',
#  '1799',
#  '363',
#  '1060',
#  '854',
#  '754',
#  '1349',
#  '699',
#  '309',
#  '489',
#  '923',
#  '459',
#  '449',
#  '2799',
#  '813',
#  '1499',
#  '1049',
#  '1399',
#  '1849',
#  '793',
#  '1199',
#  '1549',
#  '2397',
#  '779',
#  '989',
#  '1085',
#  '2824',
#  '260',
#  '999',
#  '698',
#  '839',
#  '914',
#  '6099',
#  '959',
#  '1379',
#  '1045',
#  '1845',
#  '493',
#  '742',
#  '1749',
#  '3055',
#  '1398',
#  '439',
#  '1949',
#  '1449',
#  '597',
#  '779',
#  '1407',
#  '349',
#  '549',
#  '1499',
#  '931',
#  '589',
#  '1031',
#  '1149',
#  '1279',
#  '677',
#  '899',
#  '1363',
#  '794',
#  '2456',
#  '832',
#  '859',
#  '769',
#  '891',
#  '1269',
#  '398',
#  '330',
#  '1499',
#  '859',
#  '689',
#  '899',
#  '390',
#  '575',
#  '3890',
#  '846',
#  '589',
#  '1145',
#  '889',
#  '879',
#  '1079',
#  '985',
#  '559',
#  '2999',
#  '675',
#  '2040',
#  '819',
#  '1799',
#  '469',
#  '1849',
#  '702',
#  '949',
#  '445',
#  '1059',
#  '2499',
#  '1699',
#  '1142',
#  '444',
#  '722',
#  '657',
#  '565',
#  '799',
#  '1499',
#  '467',
#  '1018',
#  '880',
#  '1958',
#  '1549',
#  '735',
#  '2499',
#  '812',
#  '713',
#  '1099',
#  '745',
#  '489',
#  '849',
#  '859',
#  '428',
#  '829',
#  '579',
#  '951',
#  '659',
#  '1097',
#  '977',
#  '1179',
#  '659',
#  '199',
#  '1187',
#  '489',
#  '1829',
#  '739',
#  '1299',
#  '979',
#  '2884',
#  '499',
#  '1468',
#  '509',
#  '2122',
#  '649',
#  '549',
#  '1265',
#  '359',
#  '1975',
#  '1043',
#  '819',
#  '469',
#  '999',
#  '2499',
#  '2099',
#  '469',
#  '275',
#  '844',
#  '2449',
#  '459',
#  '980',
#  '485',
#  '1292',
#  '589',
#  '1094',
#  '902',
#  '659',
#  '292',
#  '549',
#  '1049',
#  '1335',
#  '2639',
#  '1199',
#  '943',
#  '1334',
#  '449',
#  '999',
#  '1268',
#  '1049',
#  '1144',
#  '274',
#  '1142',
#  '274',
#  '899',
#  '716',
#  '2099',
#  '1579',
#  '1129',
#  '279',
#  '1607',
#  '375',
#  '663',
#  '2027',
#  '1304',
#  '1409',
#  '1738',
#  '1403',
#  '970',
#  '321',
#  '999',
#  '557',
#  '1427',
#  '439',
#  '945',
#  '719',
#  '639',
#  '499',
#  '389',
#  '1085',
#  '809',
#  '899',
#  '1750',
#  '1099',
#  '426',
#  '2199',
#  '489',
#  '869',
#  '488',
#  '553',
#  '309',
#  '286',
#  '846',
#  '1191',
#  '403',
#  '1655',
#  '1099',
#  '1748',
#  '2282',
#  '549',
#  '1369',
#  '2135',
#  '2509',
#  '1039',
#  '1591',
#  '693',
#  '1349',
#  '778',
#  '499',
#  '1229',
#  '938',
#  '2712',
#  '2625',
#  '306',
#  '1529',
#  '1144',
#  '879',
#  '2249',
#  '1873',
#  '1747',
#  '1680',
#  '409',
#  '304',
#  '1925',
#  '1943',
#  '469',
#  '789',
#  '928',
#  '598',
#  '689',
#  '1500',
#  '539',
#  '1215',
#  '1899',
#  '449',
#  '1427',
#  '597',
#  '2799',
#  '1159',
#  '1142',
#  '1099',
#  '1999',
#  '299',
#  '269',
#  '1010',
#  '599',
#  '2445',
#  '2449',
#  '1695',
#  '347',
#  '2199',
#  '2382',
#  '559',
#  '519',
#  '749',
#  '1429',
#  '349',
#  '1099',
#  '1179',
#  '441',
#  '1993',
#  '1027',
#  '2589',
#  '589',
#  '1975',
#  '1534',
#  '1345',
#  '979',
#  '479',
#  '2046',
#  '989',
#  '1799',
#  '639',
#  '544',
#  '435',
#  '749',
#  '799',
#  '2090',
#  '304',
#  '469',
#  '759',
#  '1699',
#  '1858',
#  '1999',
#  '1154',
#  '1275',
#  '1841',
#  '1299',
#  '740',
#  '2408',
#  '1364',
#  '675',
#  '1672',
#  '1262',
#  '586',
#  '726',
#  '248',
#  '565',
#  '1049',
#  '2338',
#  '1899',
#  '1798',
#  '1950',
#  '1011',
#  '2799',
#  '1350',
#  '579',
#  '1269',
#  '1099',
#  '898',
#  '1749',
#  '949',
#  '911',
#  '340',
#  '618',
#  '1599',
#  '299',
#  '265',
#  '949',
#  '1224',
#  '613',
#  '1323',
#  '1149',
#  '899',
#  '639',
#  '836',
#  '1219',
#  '1399',
#  '245',
#  '521',
#  '2968',
#  '889',
#  '1504',
#  '1399',
#  '1399',
#  '1279',
#  '689',
#  '889',
#  '1340',
#  '799',
#  '459',
#  '585',
#  '1377',
#  '3012',
#  '860',
#  '1299',
#  '369',
#  '1649',
#  '1369',
#  '797',
#  '398',
#  '1799',
#  '859',
#  '1399',
#  '735',
#  '1145',
#  '798',
#  '349',
#  '705',
#  '785',
#  '462',
#  '397',
#  '1729',
#  '499',
#  '1116',
#  '2699',
#  '544',
#  '1280',
#  '224',
#  '255',
#  '949',
#  '568',
#  '617',
#  '349',
#  '630',
#  '1965',
#  '2999',
#  '839',
#  '1599',
#  '959',
#  '739',
#  '344',
#  '990',
#  '1860',
#  '389',
#  '649',
#  '830',
#  '685',
#  '249',
#  '1865',
#  '2663',
#  '2729',
#  '749',
#  '389',
#  '1008',
#  '719',
#  '1537',
#  '295',
#  '2349',
#  '1498',
#  '1673',
#  '609',
#  '1770',
#  '739',
#  '949',
#  '603',
#  '1699',
#  '529',
#  '459',
#  '2025',
#  '1474',
#  '1670',
#  '1763',
#  '1219',
#  '668',
#  '329',
#  '2199',
#  '465',
#  '2299',
#  '1399',
#  '564',
#  '1299',
#  '349',
#  '4899',
#  '879',
#  '443',
#  '359',
#  '869',
#  '1168',
#  '569',
#  '1389',
#  '2267',
#  '379',
#  '1124',
#  '1465',
#  '776',
#  '799',
#  '932',
#  '899',
#  '239',
#  '468',
#  '639',
#  '1820',
#  '1900',
#  '1479',
#  '829',
#  '579',
#  '399',
#  '906',
#  '1869',
#  '249',
#  '1757',
#  '2399',
#  '1109',
#  '520',
#  '2450',
#  '1169',
#  '450',
#  '274',
#  '919',
#  '2599',
#  '1213',
#  '1584',
#  '2799',
#  '709',
#  '1449',
#  '1191',
#  '364',
#  '1064',
#  '919',
#  '1135',
#  '1196',
#  '3147',
#  '1229',
#  '419',
#  '535',
#  '539',
#  '1486',
#  '498',
#  '955',
#  '745',
#  '1258',
#  '412',
#  '1867',
#  '817',
#  '1034',
#  '349',
#  '699',
#  '1294',
#  '1135',
#  '495',
#  '2299',
#  '1299',
#  '997',
#  '419',
#  '2051',
#  '699',
#  '1499',
#  '2813',
#  '612',
#  '545',
#  '569',
#  '318',
#  '375',
#  '699',
#  '1907',
#  '2590',
#  '973',
#  '269',
#  '1749',
#  '669',
#  '1877',
#  '689',
#  '819',
#  '399',
#  '429',
#  '621',
#  '450',
#  '795',
#  '999',
#  '1855',
#  '1191',
#  '655',
#  '1249',
#  '1089',
#  '726',
#  '298',
#  '1426',
#  '857',
#  '1179',
#  '298',
#  '265',
#  '1200',
#  '1686',
#  '836',
#  '1499',
#  '3659',
#  '1348',
#  '489',
#  '719',
#  '649',
#  '589',
#  '489',
#  '1935',
#  '649',
#  '650',
#  '559',
#  '960',
#  '779',
#  '2419',
#  '659',
#  '2094',
#  '410',
#  '1207',
#  '665',
#  '1535',
#  '999',
#  '3299',
#  '330',
#  '1649',
#  '539',
#  '1126',
#  '4389',
#  '475',
#  '1900',
#  '579',
#  '1096',
#  '849',
#  '1199',
#  '1099',
#  '1561',
#  '2868',
#  '599',
#  '1048',
#  '1859',
#  '1559',
#  '1129',
#  '849',
#  '655',
#  '470',
#  '1099',
#  '1599',
#  '298',
#  '1181',
#  '1799',
#  '1020',
#  '1099',
#  '1244',
#  '839',
#  '2370',
#  '636',
#  '2899',
#  '581',
#  '3588',
#  '2350',
#  '1764',
#  '329',
#  '2299',
#  '1891',
#  '1089',
#  '999',
#  '2299',
#  '985',
#  '1339',
#  '202',
#  '1970',
#  '959',
#  '1165',
#  '2330',
#  '299',
#  '810',
#  '1349',
#  '739',
#  '2064',
#  '1099',
#  '1499',
#  '1749',
#  '744',
#  '1389',
#  '780',
#  '629',
#  '1679',
#  '609',
#  '1749',
#  '2415',
#  '1499',
#  '961',
#  '789',
#  '1859',
#  '1799',
#  '385',
#  '2505',
#  '755',
#  '489',
#  '1090',
#  '2499',
#  '1199',
#  '1875',
#  '499',
#  '1358',
#  '585',
#  '355',
#  '619',
#  '5499',
#  '2099',
#  '519',
#  '1186',
#  '1650',
#  '2774',
#  '2419',
#  '669',
#  '325',
#  '590',
#  '1799',
#  '3072',
#  '910',
#  '713',
#  '1870',
#  '739',
#  '615',
#  '1026',
#  '2277',
#  '1468',
#  '299',
#  '1899',
#  '865',
#  '1903',
#  '787',
#  '945',
#  '449',
#  '2559',
#  '649',
#  '469',
#  '850',
#  '1349',
#  '1285',
#  '1017',
#  '2240',
#  '910',
#  '1095',
#  '1950',
#  '902',
#  '1778',
#  '1055',
#  '479',
#  '1388',
#  '735',
#  '1849',
#  '1690',
#  '398',
#  '935',
#  '912',
#  '839',
#  '1700',
#  '684',
#  '348',
#  '669',
#  '369',
#  '1799',
#  '455',
#  '1369',
#  '297',
#  '379',
#  '1265',
#  '1399',
#  '1699',
#  '1799',
#  '2649',
#  '1475',
#  '929',
#  '900',
#  '614',
#  '935',
#  '2013',
#  '1279',
#  '1649',
#  '2049',
#  '1962',
#  '2099',
#  '1483',
#  '359',
#  '789',
#  '1899',
#  '1205',
#  '3100',
#  '789',
#  '1018',
#  '499',
#  '881',
#  '960',
#  '1599',
#  '1349',
#  '1119',
#  '684',
#  '1296',
#  '1149',
#  '1975',
#  '1825',
#  '729',
#  '1650',
#  '1165',
#  '708',
#  '1149',
#  '309',
#  '1579',
#  '288',
#  '1799',
#  '1105',
#  '1669',
#  '558',
#  '1199',
#  '1639',
#  '2758',
#  '1399',
#  '530',
#  '619',
#  '1119',
#  '1299',
#  '999',
#  '1472',
#  '685',
#  '659',
#  '349',
#  '2249',
#  '1775',
#  '1460',
#  '1159',
#  '1488',
#  '3154',
#  '1899',
#  '775',
#  '1268',
#  '389',
#  '1535',
#  '1760',
#  '1009',
#  '1790',
#  '846',
#  '465',
#  '825',
#  '685',
#  '3149',
#  '695',
#  '1899',
#  '1962',
#  '2800',
#  '1180',
#  '2049',
#  '979',
#  '1002',
#  '1799',
#  '579',
#  '1749',
#  '1299',
#  '1195',
#  '549',
#  '649',
#  '915',
#  '599',
#  '806',
#  '1189',
#  '749',
#  '1119',
#  '1908',
#  '499',
#  '270',
#  '1349',
#  '889',
#  '1150',
#  '1349',
#  '380',
#  '1799',
#  '2089',
#  ...]

# %%
print(x.check_promotion_dollars('1339'))
# Out:
# True

# %%
print(x.check_promotion_dollars_fast('1339') )
# Out:
# True

# %%
import time
import random

N = 100

prices = [random.randint(100, 5000) for _ in range(N)]

prices = str(prices)

x = Inventory('laptops.csv')

total_time_no_set = 0 

for price in prices:
    start = time.time()
    x.check_promotion_dollars(price)
    end = time.time()
    total_time_no_set = end - start

total_time_set = 0
for price in prices:
    start = time.time()
    x.get_laptop_from_id_fast(price)
    end = time.time()
    total_time_set = end - start

print(total_time_no_set,total_time_set)
# Out:
# 9.131431579589844e-05 9.5367431640625e-07

# %% [markdown]
# ## Time Complexity Comparison: Dictionary vs. Loop
#
# * Loop Retrieval = 0.00009131431579589844
# * Dictionary Retrieval = 0.00000095367431640625
#
# The Dictionary lookup is 96 times faster than the loop retrieval
